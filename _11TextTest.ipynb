# %%
from transformers import CLIPProcessor, CLIPModel
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from PIL import Image

class CustomTextDataset(Dataset):
    def __init__(self, texts, labels, processor):
        self.texts = texts
        self.labels = labels
        self.processor = processor

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        return text, label

# %%
# 加载 CLIP 模型和处理器
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")

# %%
from sklearn.model_selection import train_test_split
import os
def build_dataset_from_folder(folder_path, processor):
    texts = []
    labels = []

    # 遍历文件夹中的子文件夹（假设每个子文件夹代表一个标签）
    for label, folder in enumerate(os.listdir(folder_path)):
        folder_path_full = os.path.join(folder_path, folder)

        # 确保是文件夹
        if os.path.isdir(folder_path_full):
            print(f"Processing folder: {folder}")

            # 遍历该文件夹中的所有文本文件
            for text_file in os.listdir(folder_path_full):
                text_file_path = os.path.join(folder_path_full, text_file)

                # 只处理文本文件（假设文件扩展名为 .txt）
                if text_file.endswith(".txt"):
                    print(f"Processing text file: {text_file_path}")

                    # 读取文本内容
                    with open(text_file_path, 'r') as f:
                        text = f.read()

                    # 将文本和标签添加到数据集中
                    texts.append(text)
                    labels.append(label)

    train_texts, test_texts, train_labels, test_labels = train_test_split(
        texts, labels, test_size=0.2, random_state=42,shuffle=True
    )

    train_dataset = CustomTextDataset(train_texts, train_labels, processor)
    test_dataset = CustomTextDataset(test_texts, test_labels, processor)

    return train_dataset, test_dataset

    # 使用 CustomTextDataset 创建数据集
    # dataset = CustomTextDataset(texts, labels, processor)
    # return dataset

# 文件夹路径
folder_path = r"E:\DL\data\MP3\pre"  # 请替换为实际的文件夹路径

# 创建数据集
train_dataset , test_dataset= build_dataset_from_folder(folder_path, processor)

print(len(train_dataset))
print(len(test_dataset))
# 打印数据集中的第一个样本
# print(dataset[0])  # 输出处理后的文本和标签
# Out:
# Processing folder: 1_new_text
# Processing text file: E:\DL\data\MP3\pre\1_new_text\1.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\10.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\100.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\101.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\102.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\103.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\104.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\105.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\106.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\107.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\108.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\109.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\11.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\110.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\111.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\112.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\113.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\114.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\115.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\116.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\117.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\118.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\119.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\12.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\120.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\121.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\122.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\123.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\124.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\125.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\126.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\127.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\128.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\129.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\13.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\130.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\131.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\132.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\133.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\134.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\135.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\136.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\137.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\138.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\139.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\14.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\140.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\141.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\142.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\143.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\144.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\145.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\146.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\147.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\148.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\149.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\15.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\150.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\151.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\152.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\153.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\154.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\155.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\156.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\157.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\158.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\159.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\16.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\160.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\161.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\162.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\163.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\164.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\165.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\166.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\167.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\168.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\169.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\17.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\170.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\171.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\172.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\173.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\174.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\175.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\176.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\177.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\178.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\179.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\18.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\180.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\181.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\182.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\183.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\184.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\185.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\186.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\187.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\188.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\189.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\19.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\190.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\191.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\192.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\193.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\194.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\195.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\196.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\197.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\198.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\199.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\2.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\20.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\200.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\201.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\202.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\203.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\204.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\205.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\206.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\207.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\208.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\209.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\21.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\210.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\211.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\212.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\213.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\214.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\215.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\216.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\217.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\218.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\219.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\22.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\220.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\221.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\222.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\223.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\224.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\225.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\226.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\227.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\228.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\229.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\23.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\230.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\231.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\232.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\233.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\234.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\235.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\236.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\237.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\238.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\239.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\24.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\240.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\241.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text\242.txt
# Processing text file: E:\DL\data\MP3\pre\1_new_text
txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\399.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\4.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\40.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\400.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\401.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\402.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\403.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\404.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\405.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\406.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\407.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\408.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\409.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\41.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\410.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\411.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\412.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\413.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\414.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\415.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\416.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\417.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\418.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\419.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\42.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\420.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\421.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\422.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\423.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\424.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\425.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\426.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\427.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\428.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\429.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\43.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\430.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\431.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\432.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\433.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\434.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\435.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\436.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\437.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\438.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\439.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\44.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\440.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\441.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\442.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\443.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\444.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\445.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\446.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\447.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\448.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\449.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\45.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\450.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\451.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\452.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\453.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\454.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\455.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\456.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\457.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\458.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\459.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\46.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\460.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\461.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\462.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\463.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\464.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\465.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\466.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\467.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\468.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\469.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\47.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\470.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\471.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\472.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\473.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\474.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\475.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\476.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\477.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\478.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\479.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\48.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\480.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\481.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\482.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\483.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\484.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\485.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\486.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\487.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\488.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\489.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\49.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\490.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\491.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\492.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\493.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\494.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\495.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\496.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\497.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\498.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\499.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\5.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\50.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\51.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\52.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\53.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\54.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\55.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\56.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\57.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\58.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\59.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\6.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\60.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\61.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\62.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\63.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\64.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\65.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\66.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\67.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\68.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\69.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\7.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\70.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\71.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\72.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\73.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\74.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\75.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\76.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\77.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\78.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\79.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\8.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\80.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\81.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\82.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\83.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\84.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\85.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\86.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\87.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\88.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\89.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\9.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\90.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\91.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\92.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\93.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\94.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\95.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\96.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\97.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\98.txt
# Processing text file: E:\DL\data\MP3\pre\4_new_text\99.txt
# 1390
# 348

# %%
# # 假设有不定长文本和标签
# texts = ["This is a cat", "A dog is playing", "This is a car"]
# labels = [0, 1, 2]  # 假设 0, 1, 2 分别是不同的类别


# 创建自定义数据集
# dataset = CustomTextDataset(texts, labels, processor)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)



# 创建分类头部（线性层），假设有 N 个类别
num_classes = 4  # 计算类别数量
classification_head = nn.Linear(model.config.projection_dim, num_classes)

# 将模型和分类头部放到设备（GPU 或 CPU）
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
classification_head.to(device)

# 设置优化器
optimizer = torch.optim.Adam(list(model.parameters()) + list(classification_head.parameters()), lr=1e-5)

# %%
# 训练过程
epochs = 10
for epoch in range(epochs):
    model.train()
    classification_head.train()
    total_loss = 0
    for texts_batch, labels_batch in tqdm(train_dataloader):
        texts_batch = [text for text in texts_batch]  # 需要调整为列表格式
        labels_batch = torch.tensor(labels_batch).to(device)
        # print(labels_batch.shape)
        # 处理输入文本
        # inputs = processor(text=texts_batch, return_tensors="pt",max_length=77, padding=True).to(device)
        inputs = processor(text=texts_batch, padding=True, truncation=True, max_length=77, return_tensors="pt").to(device)

        # 获取 CLIP 输出（只使用文本编码器）
        outputs = model.get_text_features(**inputs)
        text_features = outputs  # 获取文本特征向量

        # 使用分类头部进行分类
        logits = classification_head(text_features)

        # 计算损失
        loss = nn.CrossEntropyLoss()(logits, labels_batch)
        total_loss += loss.item()

        # 反向传播并更新权重
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_dataloader)}")
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]C:\Users\杨大宇\AppData\Local\Temp\ipykernel_21692\23995835.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_batch = torch.tensor(labels_batch).to(device)
# 100%|██████████| 87/87 [00:07<00:00, 10.88it/s]
# Epoch 1/10, Loss: 0.3576029969871729
# 100%|██████████| 87/87 [00:07<00:00, 11.24it/s]
# Epoch 2/10, Loss: 0.11465038596813021
# 100%|██████████| 87/87 [00:07<00:00, 11.23it/s]
# Epoch 3/10, Loss: 0.07183174829630332
# 100%|██████████| 87/87 [00:07<00:00, 11.17it/s]
# Epoch 4/10, Loss: 0.03461321513971378
# 100%|██████████| 87/87 [00:07<00:00, 11.17it/s]
# Epoch 5/10, Loss: 0.06906674386954856
# 100%|██████████| 87/87 [00:07<00:00, 11.14it/s]
# Epoch 6/10, Loss: 0.07290290915888958
# 100%|██████████| 87/87 [00:07<00:00, 11.13it/s]
# Epoch 7/10, Loss: 0.03578350944551586
# 100%|██████████| 87/87 [00:07<00:00, 11.16it/s]
# Epoch 8/10, Loss: 0.05210285521936656
# 100%|██████████| 87/87 [00:07<00:00, 11.13it/s]
# Epoch 9/10, Loss: 0.05676059003105794
# 100%|██████████| 87/87 [00:07<00:00, 11.13it/s]
# Epoch 10/10, Loss: 0.04599158184859773

# %%
from sklearn.metrics import accuracy_score

model.eval()  # 切换到评估模式

# 创建 DataLoader 用于测试集
from torch.utils.data import DataLoader

# 定义 batch size
batch_size = 16
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 评估模型
predictions = []
true_labels = []

## 不需要计算梯度
with torch.no_grad():
     for texts_batch, labels_batch in tqdm(test_dataloader):

        texts_batch = [text for text in texts_batch]  # 需要调整为列表格式
        labels_batch = torch.tensor(labels_batch).to(device)

        for label in labels_batch:
            true_labels.append(label.item())

        # print(labels_batch)

        inputs = processor(text=texts_batch, padding=True, truncation=True, max_length=77, return_tensors="pt").to(device)
        # 使用模型进行预测
        outputs = model.get_text_features(**inputs)

        # print(outputs)

        text_features = outputs

        # 使用分类头部进行推理
        logits = classification_head(text_features)


        # 获取每个样本的预测标签
        predicted_labels = torch.argmax(logits, dim=1)

        # 输出每个样本的预测标签
        for i, label in enumerate(predicted_labels):
            # print(f"样本 {i+1} 的预测标签: {label.item()}")
            predictions.append(label.item())
            # true_labels

        # print(predicted_labels)
        # print(true_labels)

        # print(logits.shape)
        # 获取最匹配的类别
        # predicted_label = torch.argmax(logits)

        # print(predicted_label)

        # break
        # # 假设模型输出的是特征，我们可以使用最大值索引来进行分类
        # predictions.extend(outputs.argmax(dim=1).cpu().numpy())  # 预测标签
        # true_labels.extend(labels_batch.cpu().numpy())  # 真实标签
        #
        # print(predictions)
        # print(true_labels)

# 计算准确度
accuracy = accuracy_score(true_labels, predictions)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]C:\Users\杨大宇\AppData\Local\Temp\ipykernel_21692\4278218246.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_batch = torch.tensor(labels_batch).to(device)
# 100%|██████████| 22/22 [00:00<00:00, 26.36it/s]
# Test Accuracy: 92.82%

# %%
# 推理过程
new_text = "This is a new image of a cat"
inputs = processor(text=[new_text], return_tensors="pt", padding=True).to(device)

# 获取 CLIP 模型的文本特征
outputs = model.get_text_features(**inputs)
text_features = outputs

# 使用分类头部进行推理
logits = classification_head(text_features)

# 获取最匹配的类别
predicted_label = torch.argmax(logits)
print(f"预测标签: {predicted_label.item()}")
# Out:
# 预测标签: 3

# %%
# 微调整个模型
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
