# %%
import os

audio_path = r'E:\大创\data\MP3'  # 确保这是正确的路径
audio_paths = []
label_texts = []

# 遍历指定的音频文件夹
for folder in os.listdir(audio_path):
    folder_path = os.path.join(audio_path, folder)

    # 确保只处理文件夹，跳过文件
    if os.path.isdir(folder_path) and folder.endswith("new"):
        print(f"Processing folder: {folder}")
        label = int(folder.split("_")[0])  # 假设标签在文件夹名中，以 "_" 分隔

        # 遍历该文件夹中的音频文件
        for audio_file in os.listdir(folder_path):
            audio_file_path = os.path.join(folder_path, audio_file)

            # 只处理音频文件（可以根据实际文件扩展名调整条件）
            if audio_file.endswith(".mp3"):
                print(f"Adding file: {audio_file_path}")
                audio_paths.append(audio_file_path)
                label_texts.append(label - 1)

        # 如果你只想处理文件夹下的第一个音频文件，可以在这里加上 break
        # break

# 输出结果
print(f"Total audio files: {len(audio_paths)}")
print(f"Total labels: {len(label_texts)}")
# Out:
# Processing folder: 1_new
# Adding file: E:\大创\data\MP3\1_new\0.mp3
# Adding file: E:\大创\data\MP3\1_new\1.mp3
# Adding file: E:\大创\data\MP3\1_new\10.mp3
# Adding file: E:\大创\data\MP3\1_new\100.mp3
# Adding file: E:\大创\data\MP3\1_new\101.mp3
# Adding file: E:\大创\data\MP3\1_new\102.mp3
# Adding file: E:\大创\data\MP3\1_new\103.mp3
# Adding file: E:\大创\data\MP3\1_new\104.mp3
# Adding file: E:\大创\data\MP3\1_new\105.mp3
# Adding file: E:\大创\data\MP3\1_new\106.mp3
# Adding file: E:\大创\data\MP3\1_new\107.mp3
# Adding file: E:\大创\data\MP3\1_new\108.mp3
# Adding file: E:\大创\data\MP3\1_new\109.mp3
# Adding file: E:\大创\data\MP3\1_new\11.mp3
# Adding file: E:\大创\data\MP3\1_new\110.mp3
# Adding file: E:\大创\data\MP3\1_new\111.mp3
# Adding file: E:\大创\data\MP3\1_new\112.mp3
# Adding file: E:\大创\data\MP3\1_new\113.mp3
# Adding file: E:\大创\data\MP3\1_new\114.mp3
# Adding file: E:\大创\data\MP3\1_new\115.mp3
# Adding file: E:\大创\data\MP3\1_new\116.mp3
# Adding file: E:\大创\data\MP3\1_new\117.mp3
# Adding file: E:\大创\data\MP3\1_new\118.mp3
# Adding file: E:\大创\data\MP3\1_new\119.mp3
# Adding file: E:\大创\data\MP3\1_new\12.mp3
# Adding file: E:\大创\data\MP3\1_new\120.mp3
# Adding file: E:\大创\data\MP3\1_new\121.mp3
# Adding file: E:\大创\data\MP3\1_new\122.mp3
# Adding file: E:\大创\data\MP3\1_new\123.mp3
# Adding file: E:\大创\data\MP3\1_new\124.mp3
# Adding file: E:\大创\data\MP3\1_new\125.mp3
# Adding file: E:\大创\data\MP3\1_new\126.mp3
# Adding file: E:\大创\data\MP3\1_new\127.mp3
# Adding file: E:\大创\data\MP3\1_new\128.mp3
# Adding file: E:\大创\data\MP3\1_new\129.mp3
# Adding file: E:\大创\data\MP3\1_new\13.mp3
# Adding file: E:\大创\data\MP3\1_new\130.mp3
# Adding file: E:\大创\data\MP3\1_new\131.mp3
# Adding file: E:\大创\data\MP3\1_new\78.mp3
# Adding file: E:\大创\data\MP3\1_new\79.mp3
# Adding file: E:\大创\data\MP3\1_new\8.mp3
# Adding file: E:\大创\data\MP3\1_new\80.mp3
# Adding file: E:\大创\data\MP3\1_new\81.mp3
# Adding file: E:\大创\data\MP3\1_new\82.mp3
# Adding file: E:\大创\data\MP3\1_new\83.mp3
# Adding file: E:\大创\data\MP3\1_new\84.mp3
# Adding file: E:\大创\data\MP3\1_new\85.mp3
# Adding file: E:\大创\data\MP3\1_new\86.mp3
# Adding file: E:\大创\data\MP3\1_new\87.mp3
# Adding file: E:\大创\data\MP3\1_new\88.mp3
# Adding file: E:\大创\data\MP3\1_new\89.mp3
# Adding file: E:\大创\data\MP3\1_new\9.mp3
# Adding file: E:\大创\data\MP3\1_new\90.mp3
# Adding file: E:\大创\data\MP3\1_new\91.mp3
# Adding file: E:\大创\data\MP3\1_new\92.mp3
# Adding file: E:\大创\data\MP3\1_new\93.mp3
# Adding file: E:\大创\data\MP3\1_new\94.mp3
# Adding file: E:\大创\data\MP3\1_new\95.mp3
# Adding file: E:\大创\data\MP3\1_new\96.mp3
# Adding file: E:\大创\data\MP3\1_new\97.mp3
# Adding file: E:\大创\data\MP3\1_new\98.mp3
# Adding file: E:\大创\data\MP3\1_new\99.mp3
# Processing folder: 2_new
# Adding file: E:\大创\data\MP3\2_new\0.mp3
# Adding file: E:\大创\data\MP3\2_new\1.mp3
# Adding file: E:\大创\data\MP3\2_new\10.mp3
# Adding file: E:\大创\data\MP3\2_new\100.mp3
# Adding file: E:\大创\data\MP3\2_new\101.mp3
# Adding file: E:\大创\data\MP3\2_new\102.mp3
# Adding file: E:\大创\data\MP3\2_new\103.mp3
# Adding file: E:\大创\data\MP3\2_new\104.mp3
# Adding file: E:\大创\data\MP3\2_new\105.mp3
# Adding file: E:\大创\data\MP3\2_new\106.mp3
# Adding file: E:\大创\data\MP3\2_new\107.mp3
# Adding file: E:\大创\data\MP3\2_new\108.mp3
# Adding file: E:\大创\data\MP3\2_new\109.mp3
# Adding file: E:\大创\data\MP3\2_new\11.mp3
# Adding file: E:\大创\data\MP3\2_new\110.mp3
# Adding file: E:\大创\data\MP3\2_new\111.mp3
# Adding file: E:\大创\data\MP3\2_new\112.mp3
# Adding file: E:\大创\data\MP3\2_new\113.mp3
# Adding file: E:\大创\data\MP3\2_new\114.mp3
# Adding file: E:\大创\data\MP3\2_new\115.mp3
# Adding file: E:\大创\data\MP3\2_new\116.mp3
# Adding file: E:\大创\data\MP3\2_new\117.mp3
# Adding file: E:\大创\data\MP3\2_new\118.mp3
# Adding file: E:\大创\data\MP3\2_new\119.mp3
# Adding file: E:\大创\data\MP3\2_new\12.mp3
# Adding file: E:\大创\data\MP3\2_new\120.mp3
# Adding file: E:\大创\data\MP3\2_new\121.mp3
# Adding file: E:\大创\data\MP3\2_new\122.mp3
# Adding file: E:\大创\data\MP3\2_new\123.mp3
# Adding file: E:\大创\data\MP3\2_new\124.mp3
# Adding file: E:\大创\data\MP3\2_new\125.mp3
# Adding file: E:\大创\data\MP3\2_new\126.mp3
# Adding file: E:\大创\data\MP3\2_new\127.mp3
# Adding file: E:\大创\data\MP3\2_new\128.mp3
# Adding file: E:\大创\data\MP3\2_new\129.mp3
# Adding file: E:\大创\data\MP3\2_new\13.mp3
# Adding file: E:\大创\data\MP3\2_new\130.mp3
# Adding file: E:\大创\data\MP3\2_new\131.mp3
# Adding file: E:\大创\data\MP3\2_new\132.mp3
# Adding file: E:\大创\data\MP3\2_new\133.mp3
# Adding file: E:\大创\data\MP3\2_new\134.mp3
# Adding file: E:\大创\data\MP3\2_new\135.mp3
# Adding file: E:\大创\data\MP3\2_new\136.mp3
# Adding file: E:\大创\data\MP3\2_new\137.mp3
# Adding file: E:\大创\data\MP3\2_new\138.mp3
# Adding file: E:\大创\data\MP3\2_new\139.mp3
# Adding file: E:\大创\data\MP3\2_new\14.mp3
# Adding file: E:\大创\data\MP3\2_new\140.mp3
# Adding file: E:\大创\data\MP3\2_new\141.mp3
# Adding file: E:\大创\data\MP3\2_new\142.mp3
# Adding file: E:\大创\data\MP3\2_new\143.mp3
# Adding file: E:\大创\data\MP3\2_new\144.mp3
# Adding file: E:\大创\data\MP3\2_new\145.mp3
# Adding file: E:\大创\data\MP3\2_new\146.mp3
# Adding file: E:\大创\data\MP3\2_new\147.mp3
# Adding file: E:\大创\data\MP3\2_new\148.mp3
# Adding file: E:\大创\data\MP3\2_new\149.mp3
# Adding file: E:\大创\data\MP3\2_new\15.mp3
# Adding file: E:\大创\data\MP3\2_new\150.mp3
# Adding file: E:\大创\data\MP3\2_new\151.mp3
# Adding file: E:\大创\data\MP3\2_new\152.mp3
# Adding file: E:\大创\data\MP3\2_new\153.mp3
# Adding file: E:\大创\data\MP3\2_new\154.mp3
# Adding file: E:\大创\data\MP3\2_new\155.mp3
# Adding file: E:\大创\data\MP3\2_new\156.mp3
# Adding file: E:\大创\data\MP3\2_new\157.mp3
# Adding file: E:\大创\data\MP3\2_new\158.mp3
# Adding file: E:\大创\data\MP3\2_new\159.mp3
# Adding file: E:\大创\data\MP3\2_new\16.mp3
# Adding file: E:\大创\data\MP3\2_new\160.mp3
# Adding file: E:\大创\data\MP3\2_new\161.mp3
# Adding file: E:\大创\data\MP3\2_new\162.mp3
# Adding file: E:\大创\data\MP3\2_new\163.mp3
# Adding file: E:\大创\data\MP3\2_new\164.mp3
# Adding file: E:\大创\data\MP3\2_new\165.mp3
# Adding file: E:\大创\data\MP3\2_new\166.mp3
# Adding file: E:\大创\data\MP3\2_new\167.mp3
# Adding file: E:\大创\data\MP3\2_new\168.mp3
# Adding file: E:\大创\data\MP3\2_new\169.mp3
# Adding file: E:\大创\data\MP3\2_new\17.mp3
# Adding file: E:\大创\data\MP3\2_new\170.mp3
# Adding file: E:\大创\data\MP3\2_new\171.mp3
# Adding file: E:\大创\data\MP3\2_new\172.mp3
# Adding file: E:\大创\data\MP3\2_new\173.mp3
# Adding file: E:\大创\data\MP3\2_new\174.mp3
# Adding file: E:\大创\data\MP3\2_new\175.mp3
# Adding file: E:\大创\data\MP3\2_new\176.mp3
# Adding file: E:\大创\data\MP3\2_new\177.mp3
# Adding file: E:\大创\data\MP3\2_new\178.mp3
# Adding file: E:\大创\data\MP3\2_new\179.mp3
# Adding file: E:\大创\data\MP3\2_new\18.mp3
# Adding file: E:\大创\data\MP3\2_new\180.mp3
# Adding file: E:\大创\data\MP3\2_new\181.mp3
# Adding file: E:\大创\data\MP3\2_new\182.mp3
# Adding file: E:\大创\data\MP3\2_new\183.mp3
# Adding file: E:\大创\data\MP3\2_new\184.mp3
# Adding file: E:\大创\data\MP3\2_new\185.mp3
# Adding file: E:\大创\data\MP3\2_new\186.mp3
# Adding file: E:\大创\data\MP3\2_new\187.mp3
# Adding file: E:\大创\data\MP3\2_new\188.mp3
# Adding file: E:\大创\data\MP3\2_new\189.mp3
# Adding file: E:\大创\data\MP3\2_new\19.mp3
# Adding file: E:\大创\data\MP3\2_new\190.mp3
# Adding file: E:\大创\data\MP3\2_new\191.mp3
# Adding file: E:\大创\data\MP3\2_new\192.mp3
# Adding file: E:\大创\data\MP3\2_new\193.mp3
# Adding file: E:\大创\data\MP3\2_new\194.mp3
# Adding file: E:\大创\data\MP3\2_new\195.mp3
# Adding file: E:\大创\data\MP3\2_new\196.mp3
# Adding file: E:\大创\data\MP3\2_new\197.mp3
# Adding file: E:\大创\data\MP3\2_new\198.mp3
# Adding file: E:\大创\data\MP3\2_new\199.mp3
# Adding file: E:\大创\data\MP3\2_new\2.mp3
# Adding file: E:\大创\data\MP3\2_new\20.mp3
# Adding file: E:\大创\data\MP3\2_new\200.mp3
# Adding file: E:\大创\data\MP3\2_new\201.mp3
# Adding file: E:\大创\data\MP3\2_new\202.mp3
# Adding file: E:\大创\data\MP3\2_new\203.mp3
# Adding file: E:\大创\data\MP3\2_new\204.mp3
# Adding file: E:\大创\data\MP3\2_new\205.mp3
# Adding file: E:\大创\data\MP3\2_new\206.mp3
# Adding file: E:\大创\data\MP3\2_new\207.mp3
# Adding file: E:\大创\data\MP3\2_new\208.mp3
# Adding file: E:\大创\data\MP3\2_new\209.mp3
# Adding file: E:\大创\data\MP3\2_new\21.mp3
# Adding file: E:\大创\data\MP3\2_new\210.mp3
# Adding file: E:\大创\data\MP3\2_new\211.mp3
# Adding file: E:\大创\data\MP3\2_new\212.mp3
# Adding file: E:\大创\data\MP3\2_new\213.mp3
# Adding file: E:\大创\data\MP3\2_new\214.mp3
# Adding file: E:\大创\data\MP3\2_new\215.mp3
# Adding file: E:\大创\data\MP3\2_new\216.mp3
# Adding file: E:\大创\data\MP3\2_new\217.mp3
# Adding file: E:\大创\data\MP3\2_new\218.mp3
# Adding file: E:\大创\data\MP3\2_new\219.mp3
# Adding file: E:\大创\data\MP3\2_new\22.mp3
# Adding file: E:\大创\data\MP3\2_new\220.mp3
# Adding file: E:\大创\data\MP3\2_new\221.mp3
# Adding file: E:\大创\data\MP3\2_new\222.mp3
# Adding file: E:\大创\data\MP3\2_new\223.mp3
# Adding file: E:\大创\data\MP3\2_new\224.mp3
# Adding file: E:\大创\data\MP3\2_new\225.mp3
# Adding file: E:\大创\data\MP3\2_new\226.mp3
# Adding file: E:\大创\data\MP3\2_new\227.mp3
# Adding file: E:\大创\data\MP3\2_new\228.mp3
# Adding file: E:\大创\data\MP3\2_new\229.mp3
# Adding file: E:\大创\data\MP3\2_new\23.mp3
# Adding file: E:\大创\data\MP3\2_new\230.mp3
# Adding file: E:\大创\data\MP3\2_new\231.mp3
# Adding file: E:\大创\data\MP3\2_new\232.mp3
# Adding file: E:\大创\data\MP3\2_new\233.mp3
# Adding file: E:\大创\data\MP3\2_new\234.mp3
# Adding file: E:\大创\data\MP3\2_new\235.mp3
# Adding file: E:\大创\data\MP3\2_new\236.mp3
# Adding file: E:\大创\data\MP3\2_new\237.mp3
# Adding file: E:\大创\data\MP3\2_new\238.mp3
# Adding file: E:\大创\data\MP3\2_new\239.mp3
# Adding file: E:\大创\data\MP3\2_new\24.mp3
# Adding file: E:\大创\data\MP3\2_new\240.mp3
# Adding file: E:\大创\data\MP3\2_new\241.mp3
# Adding file: E:\大创\data\MP3\2_new\242.mp3
# Adding file: E:\大创\data\MP3\2_new\243.mp3
# Adding file: E:\大创\data\MP3\2_new\244.mp3
# Adding file: E:\大创\data\MP3\2_new\245.mp3
# Adding file: E:\大创\data\MP3\2_new\246.mp3
# Adding file: E:\大创\data\MP3\2_new\247.mp3
# Adding file: E:\大创\data\MP3\2_new\248.mp3
# Adding file: E:\大创\data\MP3\2_new\249.mp3
# Adding file: E:\大创\data\MP3\2_new\25.mp3
# Adding file: E:\大创\data\MP3\2_new\250.mp3
# Adding file: E:\大创\data\MP3\2_new\251.mp3
# Adding file: E:\大创\data\MP3\2_new\252.mp3
# Adding file: E:\大创\data\MP3\2_new\253.mp3
# Adding file: E:\大创\data\MP3\2_new\254.mp3
# Adding file: E:\大创\data\MP3\2_new\255.mp3
# Adding file: E:\大创\data\MP3\2_new\256.mp3
# Adding file: E:\大创\data\MP3\2_new\257.mp3
# Adding file: E:\大创\data\MP3\2_new\258.mp3
# Adding file: E:\大创\data\MP3\2_new\259.mp3
# Adding file: E:\大创\data\MP3\2_new\26.mp3
# Adding file: E:\大创\data\MP3\2_new\260.mp3
# Adding file: E:\大创\data\MP3\2_new\261.mp3
# Adding file: E:\大创\data\MP3\2_new\262.mp3
# Adding file: E:\大创\data\MP3\2_new\263.mp3
# Adding file: E:\大创\data\MP3\2_new\264.mp3
# Adding file: E:\大创\data\MP3\2_new\265.mp3
# Adding file: E:\大创\data\MP3\2_new\266.mp3
# Adding file: E:\大创\data\MP3\2_new\267.mp3
# Adding file: E:\大创\data\MP3\2_new\268.mp3
# Adding file: E:\大创\data\MP3\2_new\269.mp3
# Adding file: E:\大创\data\MP3\2_new\27.mp3
# Adding file: E:\大创\data\MP3\2_new\270.mp3
# Adding file: E:\大创\data\MP3\2_new\271.mp3
# Adding file: E:\大创\data\MP3\2_new\272.mp3
# Adding file: E:\大创\data\MP3\2_new\273.mp3
# Adding file: E:\大创\data\MP3\2_new\274.mp3
# Adding file: E:\大创\data\MP3\2_new\275.mp3
# Adding file: E:\大创\data\MP3\2_new\276.mp3
# Adding file: E:\大创\data\MP3\2_new\277.mp3
# Adding file: E:\大创\data\MP3\2_new\278.mp3
# Adding file: E:\大创\data\MP3\2_new\279.mp3
# Adding file: E:\大创\data\MP3\2_new\28.mp3
# Adding file: E:\大创\data\MP3\2_new\280.mp3
# Adding file: E:\大创\data\MP3\2_new\281.mp3
# Adding file: E:\大创\data\MP3\2_new\282.mp3
# Adding file: E:\大创\data\MP3\2_new\283.mp3
# Adding file: E:\大创\data\MP3\2_new\284.mp3
# Adding file: E:\大创\data\MP3\2_new\285.mp3
# Adding file: E:\大创\data\MP3\2_new\286.mp3
# Adding file: E:\大创\data\MP3\2_new\287.mp3
# Adding file: E:\大创\data\MP3\2_new\288.mp3
# Adding file: E:\大创\data\MP3\2_new\289.mp3
# Adding file: E:\大创\data\MP3\2_new\29.mp3
# Adding file: E:\大创\data\MP3\2_new\290.mp3
# Adding file: E:\大创\data\MP3\2_new\291.mp3
# Adding file: E:\大创\data\MP3\2_new\292.mp3
# Adding file: E:\大创\data\MP3\2_new\293.mp3
# Adding file: E:\大创\data\MP3\2_new\294.mp3
# Adding file: E:\大创\data\MP3\2_new\295.mp3
# Adding file: E:\大创\data\MP3\2_new\296.mp3
# Adding file: E:\大创\data\MP3\2_new\297.mp3
# Adding file: E:\大创\data\MP3\2_new\298.mp3
# Adding file: E:\大创\data\MP3\2_new\299.mp3
# Adding file: E:\大创\data\MP3\2_new\3.mp3
# Adding file: E:\大创\data\MP3\2_new\30.mp3
# Adding file: E:\大创\data\MP3\2_new\300.mp3
# Adding file: E:\大创\data\MP3\2_new\301.mp3
# Adding file: E:\大创\data\MP3\2_new\302.mp3
# Adding file: E:\大创\data\MP3\2_new\303.mp3
# Adding file: E:\大创\data\MP3\2_new\304.mp3
# Adding file: E:\大创\data\MP3\2_new\305.mp3
# Adding file: E:\大创\data\MP3\2_new\306.mp3
# Adding file: E:\大创\data\MP3\2_new\307.mp3
# Adding file: E:\大创\data\MP3\2_new\308.mp3
# Adding file: E:\大创\data\MP3\2_new\309.mp3
# Adding file: E:\大创\data\MP3\2_new\31.mp3
# Adding file: E:\大创\data\MP3\2_new\310.mp3
# Adding file: E:\大创\data\MP3\2_new\311.mp3
# Adding file: E:\大创\data\MP3\2_new\312.mp3
# Adding file: E:\大创\data\MP3\2_new\313.mp3
# Adding file: E:\大创\data\MP3\2_new\314.mp3
# Adding file: E:\大创\data\MP3\2_new\315.mp3
# Adding file: E:\大创\data\MP3\2_new\316.mp3
# Adding file: E:\大创\data\MP3\2_new\317.mp3
# Adding file: E:\大创\data\MP3\2_new\318.mp3
# Adding file: E:\大创\data\MP3\2_new\319.mp3
# Adding file: E:\大创\data\MP3\2_new\32.mp3
# Adding file: E:\大创\data\MP3\2_new\320.mp3
# Adding file: E:\大创\data\MP3\2_new\321.mp3
# Adding file: E:\大创\data\MP3\2_new\322.mp3
# Adding file: E:\大创\data\MP3\2_new\323.mp3
# Adding file: E:\大创\data\MP3\2_new\324.mp3
# Adding file: E:\大创\data\MP3\2_new\325.mp3
# Adding file: E:\大创\data\MP3\2_new\326.mp3
# Adding file: E:\大创\data\MP3\2_new\327.mp3
# Adding file: E:\大创\data\MP3\2_new\328.mp3
# Adding file: E:\大创\data\MP3\2_new\329.mp3
# Adding file: E:\大创\data\MP3\2_new\33.mp3
# Adding file: E:\大创\data\MP3\2_new\330.mp3
# Adding file: E:\大创\data\MP3\2_new\331.mp3
# Adding file: E:\大创\data\MP3\2_new\332.mp3
# Adding file: E:\大创\data\MP3\2_new\333.mp3
# Adding file: E:\大创\data\MP3\2_new\334.mp3
# Adding file: E:\大创\data\MP3\2_new\335.mp3
# Adding file: E:\大创\data\MP3\2_new\336.mp3
# Adding file: E:\大创\data\MP3\2_new\337.mp3
# Adding file: E:\大创\data\MP3\2_new\338.mp3
# Adding file: E:\大创\data\MP3\2_new\339.mp3
# Adding file: E:\大创\data\MP3\2_new\34.mp3
# Adding file: E:\大创\data\MP3\2_new\340.mp3
# Adding file: E:\大创\data\MP3\2_new\341.mp3
# Adding file: E:\大创\data\MP3\2_new\342.mp3
# Adding file: E:\大创\data\MP3\2_new\343.mp3
# Adding file: E:\大创\data\MP3\2_new\344.mp3
# Adding file: E:\大创\data\MP3\2_new\345.mp3
# Adding file: E:\大创\data\MP3\2_new\346.mp3
# Adding file: E:\大创\data\MP3\2_new\347.mp3
# Adding file: E:\大创\data\MP3\2_new\348.mp3
# Adding file: E:\大创\data\MP3\2_new\349.mp3
# Adding file: E:\大创\data\MP3\2_new\35.mp3
# Adding file: E:\大创\data\MP3\2_new\350.mp3
# Adding file: E:\大创\data\MP3\2_new\351.mp3
# Adding file: E:\大创\data\MP3\2_new\352.mp3
# Adding file: E:\大创\data\MP3\2_new\353.mp3
# Adding file: E:\大创\data\MP3\2_new\354.mp3
# Adding file: E:\大创\data\MP3\2_new\355.mp3
# Adding file: E:\大创\data\MP3\2_new\356.mp3
# Adding file: E:\大创\data\MP3\2_new\357.mp3
# Adding file: E:\大创\data\MP3\2_new\358.mp3
# Adding file: E:\大创\data\MP3\2_new\359.mp3
# Adding file: E:\大创\data\MP3\2_new\36.mp3
# Adding file: E:\大创\data\MP3\2_new\360.mp3
# Adding file: E:\大创\data\MP3\2_new\361.mp3
# Adding file: E:\大创\data\MP3\2_new\362.mp3
# Adding file: E:\大创\data\MP3\2_new\363.mp3
# Adding file: E:\大创\data\MP3\2_new\364.mp3
# Adding file: E:\大创\data\MP3\2_new\365.mp3
# Adding file: E:\大创\data\MP3\2_new\366.mp3
# Adding file: E:\大创\data\MP3\2_new\367.mp3
# Adding file: E:\大创\data\MP3\2_new\368.mp3
# Adding file: E:\大创\data\MP3\2_new\369.mp3
# Adding file: E:\大创\data\MP3\2_new\37.mp3
# Adding file: E:\大创\data\MP3\2_new\370.mp3
# Adding file: E:\大创\data\MP3\2_new\371.mp3
# Adding file: E:\大创\data\MP3\2_new\372.mp3
# Adding file: E:\大创\data\MP3\2_new\373.mp3
# Adding file: E:\大创\data\MP3\2_new\374.mp3
# Adding file: E:\大创\data\MP3\2_new\375.mp3
# Adding file: E:\大创\data\MP3\2_new\376.mp3
# Adding file: E:\大创\data\MP3\2_new\377.mp3
# Adding file: E:\大创\data\MP3\2_new\378.mp3
# Adding file: E:\大创\data\MP3\2_new\379.mp3
# Adding file: E:\大创\data\MP3\2_new\38.mp3
# Adding file: E:\大创\data\MP3\2_new\380.mp3
# Adding file: E:\大创\data\MP3\2_new\381.mp3
# Adding file: E:\大创\data\MP3\2_new\382.mp3
# Adding file: E:\大创\data\MP3\2_new\383.mp3
# Adding file: E:\大创\data\MP3\2_new\384.mp3
# Adding file: E:\大创\data\MP3\2_new\385.mp3
# Adding file: E:\大创\data\MP3\2_new\386.mp3
# Adding file: E:\大创\data\MP3\2_new\387.mp3
# Adding file: E:\大创\data\MP3\2_new\388.mp3
# Adding file: E:\大创\data\MP3\2_new\389.mp3
# Adding file: E:\大创\data\MP3\2_new\39.mp3
# Adding file: E:\大创\data\MP3\2_new\390.mp3
# Adding file: E:\大创\data\MP3\2_new\391.mp3
# Adding file: E:\大创\data\MP3\2_new\392.mp3
# Adding file: E:\大创\data\MP3\2_new\393.mp3
# Adding file: E:\大创\data\MP3\2_new\394.mp3
# Adding file: E:\大创\data\MP3\2_new\395.mp3
# Adding file: E:\大创\data\MP3\2_new\396.mp3
# Adding file: E:\大创\data\MP3\2_new\397.mp3
# Adding file: E:\大创\data\MP3\2_new\398.mp3
# Adding file: E:\大创\data\MP3\2_new\399.mp3
# Adding file: E:\大创\data\MP3\2_new\4.mp3
# Adding file: E:\大创\data\MP3\2_new\40.mp3
# Adding file: E:\大创\data\MP3\2_new\400.mp3
# Adding file: E:\大创\data\MP3\2_new\401.mp3
# Adding file: E:\大创\data\MP3\2_new\402.mp3
# Adding file: E:\大创\data\MP3\2_new\403.mp3
# Adding file: E:\大创\data\MP3\2_new\404.mp3
# Adding file: E:\大创\data\MP3\2_new\405.mp3
# Adding file: E:\大创\data\MP3\2_new\406.mp3
# Adding file: E:\大创\data\MP3\2_new\407.mp3
# Adding file: E:\大创\data\MP3\2_new\408.mp3
# Adding file: E:\大创\data\MP3\2_new\409.mp3
# Adding file: E:\大创\data\MP3\2_new\41.mp3
# Adding file: E:\大创\data\MP3\2_new\410.mp3
# Adding file: E:\大创\data\MP3\2_new\411.mp3
# Adding file: E:\大创\data\MP3\2_new\412.mp3
# Adding file: E:\大创\data\MP3\2_new\413.mp3
# Adding file: E:\大创\data\MP3\2_new\414.mp3
# Adding file: E:\大创\data\MP3\2_new\415.mp3
# Adding file: E:\大创\data\MP3\2_new\416.mp3
# Adding file: E:\大创\data\MP3\2_new\417.mp3
# Adding file: E:\大创\data\MP3\2_new\418.mp3
# Adding file: E:\大创\data\MP3\2_new\419.mp3
# Adding file: E:\大创\data\MP3\2_new\42.mp3
# Adding file: E:\大创\data\MP3\2_new\420.mp3
# Adding file: E:\大创\data\MP3\2_new\421.mp3
# Adding file: E:\大创\data\MP3\2_new\422.mp3
# Adding file: E:\大创\data\MP3\2_new\423.mp3
# Adding file: E:\大创\data\MP3\2_new\424.mp3
# Adding file: E:\大创\data\MP3\2_new\425.mp3
# Adding file: E:\大创\data\MP3\2_new\426.mp3
# Adding file: E:\大创\data\MP3\2_new\427.mp3
# Adding file: E:\大创\data\MP3\2_new\428.mp3
# Adding file: E:\大创\data\MP3\2_new\429.mp3
# Adding file: E:\大创\data\MP3\2_new\43.mp3
# Adding file: E:\大创\data\MP3\2_new\430.mp3
# Adding file: E:\大创\data\MP3\2_new\431.mp3
# Adding file: E:\大创\data\MP3\2_new\432.mp3
# Adding file: E:\大创\data\MP3\2_new\433.mp3
# Adding file: E:\大创\data\MP3\2_new\434.mp3
# Adding file: E:\大创\data\MP3\2_new\435.mp3
# Adding file: E:\大创\data\MP3\2_new\436.mp3
# Adding file: E:\大创\data\MP3\2_new\437.mp3
# Adding file: E:\大创\data\MP3\2_new\438.mp3
# Adding file: E:\大创\data\MP3\2_new\439.mp3
# Adding file: E:\大创\data\MP3\2_new\44.mp3
# Adding file: E:\大创\data\MP3\2_new\440.mp3
# Adding file: E:\大创\data\MP3\2_new\441.mp3
# Adding file: E:\大创\data\MP3\2_new\442.mp3
# Adding file: E:\大创\data\MP3\2_new\443.mp3
# Adding file: E:\大创\data\MP3\2_new\444.mp3
# Adding file: E:\大创\data\MP3\2_new\445.mp3
# Adding file: E:\大创\data\MP3\2_new\446.mp3
# Adding file: E:\大创\data\MP3\2_new\447.mp3
# Adding file: E:\大创\data\MP3\2_new\448.mp3
# Adding file: E:\大创\data\MP3\2_new\449.mp3
# Adding file: E:\大创\data\MP3\2_new\45.mp3
# Adding file: E:\大创\data\MP3\2_new\450.mp3
# Adding file: E:\大创\data\MP3\2_new\451.mp3
# Adding file: E:\大创\data\MP3\2_new\452.mp3
# Adding file: E:\大创\data\MP3\2_new\453.mp3
# Adding file: E:\大创\data\MP3\2_new\454.mp3
# Adding file: E:\大创\data\MP3\2_new\455.mp3
# Adding file: E:\大创\data\MP3\2_new\456.mp3
# Adding file: E:\大创\data\MP3\2_new\457.mp3
# Adding file: E:\大创\data\MP3\2_new\458.mp3
# Adding file: E:\大创\data\MP3\2_new\459.mp3
# Adding file: E:\大创\data\MP3\2_new\46.mp3
# Adding file: E:\大创\data\MP3\2_new\460.mp3
# Adding file: E:\大创\data\MP3\2_new\461.mp3
# Adding file: E:\大创\data\MP3\2_new\462.mp3
# Adding file: E:\大创\data\MP3\2_new\463.mp3
# Adding file: E:\大创\data\MP3\2_new\464.mp3
# Adding file: E:\大创\data\MP3\2_new\465.mp3
# Adding file: E:\大创\data\MP3\2_new\466.mp3
# Adding file: E:\大创\data\MP3\2_new\467.mp3
# Adding file: E:\大创\data\MP3\2_new\468.mp3
# Adding file: E:\大创\data\MP3\2_new\469.mp3
# Adding file: E:\大创\data\MP3\2_new\47.mp3
# Adding file: E:\大创\data\MP3\2_new\470.mp3
# Adding file: E:\大创\data\MP3\2_new\471.mp3
# Adding file: E:\大创\data\MP3\2_new\472.mp3
# Adding file: E:\大创\data\MP3\2_new\473.mp3
# Adding file: E:\大创\data\MP3\2_new\474.mp3
# Adding file: E:\大创\data\MP3\2_new\475.mp3
# Adding file: E:\大创\data\MP3\2_new\476.mp3
# Adding file: E:\大创\data\MP3\2_new\477.mp3
# Adding file: E:\大创\data\MP3\2_new\478.mp3
# Adding file: E:\大创\data\MP3\2_new\479.mp3
# Adding file: E:\大创\data\MP3\2_new\48.mp3
# Adding file: E:\大创\data\MP3\2_new\480.mp3
# Adding file: E:\大创\data\MP3\2_new\481.mp3
# Adding file: E:\大创\data\MP3\2_new\482.mp3
# Adding file: E:\大创\data\MP3\2_new\483.mp3
# Adding file: E:\大创\data\MP3\2_new\484.mp3
# Adding file: E:\大创\data\MP3\2_new\485.mp3
# Adding file: E:\大创\data\MP3\2_new\486.mp3
# Adding file: E:\大创\data\MP3\2_new\487.mp3
# Adding file: E:\大创\data\MP3\2_new\488.mp3
# Adding file: E:\大创\data\MP3\2_new\489.mp3
# Adding file: E:\大创\data\MP3\2_new\49.mp3
# Adding file: E:\大创\data\MP3\2_new\490.mp3
# Adding file: E:\大创\data\MP3\2_new\491.mp3
# Adding file: E:\大创\data\MP3\2_new\492.mp3
# Adding file: E:\大创\data\MP3\2_new\493.mp3
# Adding file: E:\大创\data\MP3\2_new\494.mp3
# Adding file: E:\大创\data\MP3\2_new\495.mp3
# Adding file: E:\大创\data\MP3\2_new\496.mp3
# Adding file: E:\大创\data\MP3\2_new\497.mp3
# Adding file: E:\大创\data\MP3\2_new\498.mp3
# Adding file: E:\大创\data\MP3\2_new\499.mp3
# Adding file: E:\大创\data\MP3\2_new\5.mp3
# Adding file: E:\大创\data\MP3\2_new\50.mp3
# Adding file: E:\大创\data\MP3\2_new\51.mp3
# Adding file: E:\大创\data\MP3\2_new\52.mp3
# Adding file: E:\大创\data\MP3\2_new\53.mp3
# Adding file: E:\大创\data\MP3\2_new\54.mp3
# Adding file: E:\大创\data\MP3\2_new\55.mp3
# Adding file: E:\大创\data\MP3\2_new\56.mp3
# Adding file: E:\大创\data\MP3\2_new\57.mp3
# Adding file: E:\大创\data\MP3\2_new\58.mp3
# Adding file: E:\大创\data\MP3\2_new\59.mp3
# Adding file: E:\大创\data\MP3\2_new\6.mp3
# Adding file: E:\大创\data\MP3\2_new\60.mp3
# Adding file: E:\大创\data\MP3\2_new\61.mp3
# Adding file: E:\大创\data\MP3\2_new\62.mp3
# Adding file: E:\大创\data\MP3\2_new\63.mp3
# Adding file: E:\大创\data\MP3\2_new\64.mp3
# Adding file: E:\大创\data\MP3\2_new\65.mp3
# Adding file: E:\大创\data\MP3\2_new\66.mp3
# Adding file: E:\大创\data\MP3\2_new\67.mp3
# Adding file: E:\大创\data\MP3\2_new\68.mp3
# Adding file: E:\大创\data\MP3\2_new\69.mp3
# Adding file: E:\大创\data\MP3\2_new\7.mp3
# Adding file: E:\大创\data\MP3\2_new\70.mp3
# Adding file: E:\大创\data\MP3\2_new\71.mp3
# Adding file: E:\大创\data\MP3\2_new\72.mp3
# Adding file: E:\大创\data\MP3\2_new\73.mp3
# Adding file: E:\大创\data\MP3\2_new\74.mp3
# Adding file: E:\大创\data\MP3\2_new\75.mp3
# Adding file: E:\大创\data\MP3\2_new\76.mp3
# Adding file: E:\大创\data\MP3\2_new\77.mp3
# Adding file: E:\大创\data\MP3\2_new\78.mp3
# Adding file: E:\大创\data\MP3\2_new\79.mp3
# Adding file: E:\大创\data\MP3\2_new\8.mp3
# Adding file: E:\大创\data\MP3\2_new\80.mp3
# Adding file: E:\大创\data\MP3\2_new\81.mp3
# Adding file: E:\大创\data\MP3\2_new\82.mp3
# Adding file: E:\大创\data\MP3\2_new\83.mp3
# Adding file: E:\大创\data\MP3\2_new\84.mp3
# Adding file: E:\大创\data\MP3\2_new\85.mp3
# Adding file: E:\大创\data\MP3\2_new\86.mp3
# Adding file: E:\大创\data\MP3\2_new\87.mp3
# Adding file: E:\大创\data\MP3\2_new\88.mp3
# Adding file: E:\大创\data\MP3\2_new\89.mp3
# Adding file: E:\大创\data\MP3\2_new\9.mp3
# Adding file: E:\大创\data\MP3\2_new\90.mp3
# Adding file: E:\大创\data\MP3\2_new\91.mp3
# Adding file: E:\大创\data\MP3\2_new\92.mp3
# Adding file: E:\大创\data\MP3\2_new\93.mp3
# Adding file: E:\大创\data\MP3\2_new\94.mp3
# Adding file: E:\大创\data\MP3\2_new\95.mp3
# Adding file: E:\大创\data\MP3\2_new\96.mp3
# Adding file: E:\大创\data\MP3\2_new\97.mp3
# Adding file: E:\大创\data\MP3\2_new\98.mp3
# Adding file: E:\大创\data\MP3\2_new\99.mp3
# Processing folder: 3_new
# Adding file: E:\大创\data\MP3\3_new\0.mp3
# Adding file: E:\大创\data\MP3\3_new\1.mp3
# Adding file: E:\大创\data\MP3\3_new\10.mp3
# Adding file: E:\大创\data\MP3\3_new\100.mp3
# Adding file: E:\大创\data\MP3\3_new\101.mp3
# Adding file: E:\大创\data\MP3\3_new\102.mp3
# Adding file: E:\大创\data\MP3\3_new\103.mp3
# Adding file: E:\大创\data\MP3\3_new\104.mp3
# Adding file: E:\大创\data\MP3\3_new\105.mp3
# Adding file: E:\大创\data\MP3\3_new\106.mp3
# Adding file: E:\大创\data\MP3\3_new\107.mp3
# Adding file: E:\大创\data\MP3\3_new\108.mp3
# Adding file: E:\大创\data\MP3\3_new\109.mp3
# Adding file: E:\大创\data\MP3\3_new\11.mp3
# Adding file: E:\大创\data\MP3\3_new\110.mp3
# Adding file: E:\大创\data\MP3\3_new\111.mp3
# Adding file: E:\大创\data\MP3\3_new\112.mp3
# Adding file: E:\大创\data\MP3\3_new\113.mp3
# Adding file: E:\大创\data\MP3\3_new\114.mp3
# Adding file: E:\大创\data\MP3\3_new\115.mp3
# Adding file: E:\大创\data\MP3\3_new\116.mp3
# Adding file: E:\大创\data\MP3\3_new\117.mp3
# Adding file: E:\大创\data\MP3\3_new\118.mp3
# Adding file: E:\大创\data\MP3\3_new\119.mp3
# Adding file: E:\大创\data\MP3\3_new\12.mp3
# Adding file: E:\大创\data\MP3\3_new\120.mp3
# Adding file: E:\大创\data\MP3\3_new\121.mp3
# Adding file: E:\大创\data\MP3\3_new\122.mp3
# Adding file: E:\大创\data\MP3\3_new\123.mp3
# Adding file: E:\大创\data\MP3\3_new\124.mp3
# Adding file: E:\大创\data\MP3\3_new\125.mp3
# Adding file: E:\大创\data\MP3\3_new\126.mp3
# Adding file: E:\大创\data\MP3\3_new\127.mp3
# Adding file: E:\大创\data\MP3\3_new\128.mp3
# Adding file: E:\大创\data\MP3\3_new\129.mp3
# Adding file: E:\大创\data\MP3\3_new\13.mp3
# Adding file: E:\大创\data\MP3\3_new\130.mp3
# Adding file: E:\大创\data\MP3\3_new\131.mp3
# Adding file: E:\大创\data\MP3\3_new\132.mp3
# Adding file: E:\大创\data\MP3\3_new\133.mp3
# Adding file: E:\大创\data\MP3\3_new\134.mp3
# Adding file: E:\大创\data\MP3\3_new\135.mp3
# Adding file: E:\大创\data\MP3\3_new\136.mp3
# Adding file: E:\大创\data\MP3\3_new\137.mp3
# Adding file: E:\大创\data\MP3\3_new\138.mp3
# Adding file: E:\大创\data\MP3\3_new\139.mp3
# Adding file: E:\大创\data\MP3\3_new\14.mp3
# Adding file: E:\大创\data\MP3\3_new\140.mp3
# Adding file: E:\大创\data\MP3\3_new\141.mp3
# Adding file: E:\大创\data\MP3\3_new\142.mp3
# Adding file: E:\大创\data\MP3\3_new\143.mp3
# Adding file: E:\大创\data\MP3\3_new\144.mp3
# Adding file: E:\大创\data\MP3\3_new\145.mp3
# Adding file: E:\大创\data\MP3\3_new\146.mp3
# Adding file: E:\大创\data\MP3\3_new\147.mp3
# Adding file: E:\大创\data\MP3\3_new\148.mp3
# Adding file: E:\大创\data\MP3\3_new\149.mp3
# Adding file: E:\大创\data\MP3\3_new\15.mp3
# Adding file: E:\大创\data\MP3\3_new\150.mp3
# Adding file: E:\大创\data\MP3\3_new\151.mp3
# Adding file: E:\大创\data\MP3\3_new\152.mp3
# Adding file: E:\大创\data\MP3\3_new\153.mp3
# Adding file: E:\大创\data\MP3\3_new\154.mp3
# Adding file: E:\大创\data\MP3\3_new\155.mp3
# Adding file: E:\大创\data\MP3\3_new\156.mp3
# Adding file: E:\大创\data\MP3\3_new\157.mp3
# Adding file: E:\大创\data\MP3\3_new\158.mp3
# Adding file: E:\大创\data\MP3\3_new\159.mp3
# Adding file: E:\大创\data\MP3\3_new\16.mp3
# Adding file: E:\大创\data\MP3\3_new\160.mp3
# Adding file: E:\大创\data\MP3\3_new\161.mp3
# Adding file: E:\大创\data\MP3\3_new\162.mp3
# Adding file: E:\大创\data\MP3\3_new\163.mp3
# Adding file: E:\大创\data\MP3\3_new\164.mp3
# Adding file: E:\大创\data\MP3\3_new\165.mp3
# Adding file: E:\大创\data\MP3\3_new\166.mp3
# Adding file: E:\大创\data\MP3\3_new\167.mp3
# Adding file: E:\大创\data\MP3\3_new\168.mp3
# Adding file: E:\大创\data\MP3\3_new\169.mp3
# Adding file: E:\大创\data\MP3\3_new\17.mp3
# Adding file: E:\大创\data\MP3\3_new\170.mp3
# Adding file: E:\大创\data\MP3\3_new\171.mp3
# Adding file: E:\大创\data\MP3\3_new\172.mp3
# Adding file: E:\大创\data\MP3\3_new\173.mp3
# Adding file: E:\大创\data\MP3\3_new\174.mp3
# Adding file: E:\大创\data\MP3\3_new\175.mp3
# Adding file: E:\大创\data\MP3\3_new\176.mp3
# Adding file: E:\大创\data\MP3\3_new\177.mp3
# Adding file: E:\大创\data\MP3\3_new\178.mp3
# Adding file: E:\大创\data\MP3\3_new\179.mp3
# Adding file: E:\大创\data\MP3\3_new\18.mp3
# Adding file: E:\大创\data\MP3\3_new\180.mp3
# Adding file: E:\大创\data\MP3\3_new\181.mp3
# Adding file: E:\大创\data\MP3\3_new\182.mp3
# Adding file: E:\大创\data\MP3\3_new\183.mp3
# Adding file: E:\大创\data\MP3\3_new\184.mp3
# Adding file: E:\大创\data\MP3\3_new\185.mp3
# Adding file: E:\大创\data\MP3\3_new\186.mp3
# Adding file: E:\大创\data\MP3\3_new\187.mp3
# Adding file: E:\大创\data\MP3\3_new\188.mp3
# Adding file: E:\大创\data\MP3\3_new\189.mp3
# Adding file: E:\大创\data\MP3\3_new\19.mp3
# Adding file: E:\大创\data\MP3\3_new\190.mp3
# Adding file: E:\大创\data\MP3\3_new\191.mp3
# Adding file: E:\大创\data\MP3\3_new\192.mp3
# Adding file: E:\大创\data\MP3\3_new\193.mp3
# Adding file: E:\大创\data\MP3\3_new\194.mp3
# Adding file: E:\大创\data\MP3\3_new\195.mp3
# Adding file: E:\大创\data\MP3\3_new\196.mp3
# Adding file: E:\大创\data\MP3\3_new\197.mp3
# Adding file: E:\大创\data\MP3\3_new\198.mp3
# Adding file: E:\大创\data\MP3\3_new\199.mp3
# Adding file: E:\大创\data\MP3\3_new\2.mp3
# Adding file: E:\大创\data\MP3\3_new\20.mp3
# Adding file: E:\大创\data\MP3\3_new\200.mp3
# Adding file: E:\大创\data\MP3\3_new\201.mp3
# Adding file: E:\大创\data\MP3\3_new\202.mp3
# Adding file: E:\大创\data\MP3\3_new\203.mp3
# Adding file: E:\大创\data\MP3\3_new\204.mp3
# Adding file: E:\大创\data\MP3\3_new\205.mp3
# Adding file: E:\大创\data\MP3\3_new\206.mp3
# Adding file: E:\大创\data\MP3\3_new\207.mp3
# Adding file: E:\大创\data\MP3\3_new\208.mp3
# Adding file: E:\大创\data\MP3\3_new\209.mp3
# Adding file: E:\大创\data\MP3\3_new\21.mp3
# Adding file: E:\大创\data\MP3\3_new\210.mp3
# Adding file: E:\大创\data\MP3\3_new\211.mp3
# Adding file: E:\大创\data\MP3\3_new\212.mp3
# Adding file: E:\大创\data\MP3\3_new\213.mp3
# Adding file: E:\大创\data\MP3\3_new\214.mp3
# Adding file: E:\大创\data\MP3\3_new\215.mp3
# Adding file: E:\大创\data\MP3\3_new\216.mp3
# Adding file: E:\大创\data\MP3\4_new\88.mp3
# Adding file: E:\大创\data\MP3\4_new\89.mp3
# Adding file: E:\大创\data\MP3\4_new\9.mp3
# Adding file: E:\大创\data\MP3\4_new\90.mp3
# Adding file: E:\大创\data\MP3\4_new\91.mp3
# Adding file: E:\大创\data\MP3\4_new\92.mp3
# Adding file: E:\大创\data\MP3\4_new\93.mp3
# Adding file: E:\大创\data\MP3\4_new\94.mp3
# Adding file: E:\大创\data\MP3\4_new\95.mp3
# Adding file: E:\大创\data\MP3\4_new\96.mp3
# Adding file: E:\大创\data\MP3\4_new\97.mp3
# Adding file: E:\大创\data\MP3\4_new\98.mp3
# Adding file: E:\大创\data\MP3\4_new\99.mp3
# Total audio files: 1739
# Total labels: 1739

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class AudioClassifier(nn.Module):
    def __init__(self, num_classes=4):
        super(AudioClassifier, self).__init__()

        # 输入形状为 [batch_size, 128, 2813] -> 128 个特征，2813 个时间步
        self.conv1 = nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)  # 128 -> 256
        self.drop1 = nn.Dropout(0.2)
        self.conv2 = nn.Conv1d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)  # 256 -> 512
        self.drop2 = nn.Dropout(0.2)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)  # 最大池化减少维度

        # 添加归一化层
        self.batch_norm1 = nn.BatchNorm1d(128)  # 归一化输入的 128 个特征
        self.batch_norm2 = nn.BatchNorm1d(256)  # 归一化卷积后的 256 个特征
        self.batch_norm3 = nn.BatchNorm1d(512)  # 归一化卷积后的 512 个特征

        # 分类头
        self.fc1 = nn.Linear(512 * (2813 // 4), 1024)  # 池化后维度大小，假设池化两次减少了四分之一
        self.fc2 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = x.transpose(1, 2)  # 转换为 [batch_size, 128, 2813]，以适应 Conv1D

        # 添加归一化
        x = self.batch_norm1(x)  # 归一化
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)  # 最大池化

        x = self.batch_norm2(x)  # 归一化
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)  # 最大池化

        x = x.view(x.size(0), -1)  # 展平为一维向量
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)  # 输出四分类的 logits

        return x



# # 示例使用
# audio_data = torch.randn(16, 2813, 128)  # 输入形状为 [16, 2813, 128]
# model = AudioClassifier(num_classes=4)
# logits = model(audio_data)
#
# # 输出类别
# probs = F.softmax(logits, dim=1)  # 计算每个类别的概率
# predicted_classes = torch.argmax(probs, dim=1)  # 选择最大概率的类别
# print("Logits:", logits)  # 输出 logits（原始得分）
# print("Predicted Classes:", predicted_classes)  # 输出预测的类别
# print("Probabilities:", probs)  # 输出每个类别的概率

# %%
from sklearn.model_selection import train_test_split
import librosa
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import CLIPProcessor, CLIPModel

import torch
import torch.nn.functional as F

def pad_or_truncate_audio_features(audio_features, target_length=2813):
    """
    填充或裁剪音频特征使它们具有相同的目标长度。
    """
    current_length = audio_features.size(1)

    if current_length < target_length:
        # 使用零填充
        padding_size = target_length - current_length
        audio_features = F.pad(audio_features, (0, padding_size), "constant", 0)
    elif current_length > target_length:
        # 裁剪到目标长度
        audio_features = audio_features[:, :target_length]

    return audio_features


# 这里是音频特征提取的函数
def extract_audio_features(audio_path):
    # 加载音频文件
    y, sr = librosa.load(audio_path, sr=None)
    # 提取 Mel-spectrogram 特征
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
    # 将其转换为 log-mel spectrogram
    log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)
    return log_mel_spectrogram

# 自定义 Dataset
class AudioTextDataset(Dataset):
    def __init__(self, audio_paths, labels, processor, label_map, target_length=2813):
        self.audio_paths = audio_paths
        self.labels = labels
        self.processor = processor
        self.label_map = label_map
        self.target_length = target_length  # 这里初始化 target_length

    def __len__(self):
        return len(self.audio_paths)

    def __getitem__(self, idx):

        # 提取音频特征
        audio_features = extract_audio_features(self.audio_paths[idx])
        audio_features = torch.tensor(audio_features).float()

        # 填充或裁剪音频特征
        audio_features = pad_or_truncate_audio_features(audio_features, self.target_length)


        # 获取标签文本并进行映射
        label = self.labels[idx]
        # label_idx = self.label_map[label]  # 将标签映射为对应的索引

        return torch.tensor(audio_features).float(), torch.tensor(label).int()
    def splitData(self, rate=0.8):
        train_audio_paths, test_audio_paths, train_labels, test_labels = train_test_split(
            self.audio_paths, self.labels, test_size=(1 - rate), random_state=42
        )

        # 返回新的训练集和测试集
        train_dataset = AudioTextDataset(train_audio_paths, train_labels, self.processor, self.label_map)
        test_dataset = AudioTextDataset(test_audio_paths, test_labels, self.processor, self.label_map)

        return train_dataset, test_dataset

# %%
# 创建数据集
dataset = AudioTextDataset(audio_paths, label_texts, processor=None, label_map=None,target_length=2813)

# 划分数据集
train_dataset, test_dataset = dataset.splitData(rate=0.8)

# 打印数据集长度
print(f"训练集大小: {len(train_dataset)}")
print(f"测试集大小: {len(test_dataset)}")
# Out:
# 训练集大小: 1391
# 测试集大小: 348

# %%
train_dataloader ,test_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True),DataLoader(test_dataset,batch_size=16,shuffle=True)

# %%
import torch.optim as optim
# 创建模型实例
model = AudioClassifier(num_classes=4)

# 定义损失函数和优化器
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 训练模型
epochs = 5
for epoch in range(epochs):
    model.train()  # 设置模型为训练模式
    total_loss = 0.0
    # 在训练过程中
    for batch in train_dataloader:
        audio_data, labels = batch
        # 将标签转换为 Long 类型
        labels = labels.long()

        # 调整输入的维度为 [batch_size, 128, 2813]
        audio_data = audio_data.permute(0, 2, 1)  # 从 [batch_size, 2813, 128] 转为 [batch_size, 128, 2813]

        # 清零梯度
        optimizer.zero_grad()

        # 前向传播
        logits = model(audio_data)

        # 计算损失
        loss = loss_fn(logits, labels)
        total_loss += loss.item()

        # 反向传播和优化
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_dataloader)}")
# 在测试过程中
model.eval()  # 设置模型为评估模式
correct = 0
total = 0
with torch.no_grad():
    for batch in test_dataloader:
        audio_data, labels = batch
        # 将标签转换为 Long 类型
        labels = labels.long()

        audio_data = audio_data.permute(0, 2, 1)  # 调整输入的维度
        logits = model(audio_data)
        _, predicted = torch.max(logits, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy: {100 * correct / total}%")
# Out:
# C:\Users\杨大宇\AppData\Local\Temp\ipykernel_24296\867985385.py:63: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(audio_features).float(), torch.tensor(label).int()
# Epoch 1/5, Loss: 18.154671928568654
# Epoch 2/5, Loss: 1.0499676575534171
# Epoch 3/5, Loss: 4.176999699350355
# Epoch 4/5, Loss: 4.377821406953777
# Epoch 5/5, Loss: 3.4635480953642737
# Accuracy: 99.71264367816092%
